# %% [markdown]
# <h1>Entertainer Data Analytics</h1>

# %% [markdown]
# <p>Domain : Film and Entertainment

# %% [markdown]
# <h3>Overview:</h3>
# <p>By leveraging data analytics techniques, the project aims to provide actionable insights into entertainer preferences, audience demographics, performance trends, and audience satisfaction.<p>
# <h3>Tools and Technologies:</h3>
# <ul>
# <li>Language: Python
# <li>Libraries: Pandas, NumPy,Matplotlib, Seaborn
# <li>Environment: Jupyter Notebook
# </ul>
# <h3>Deliverables:</h3>
# <ul>
# <li>Jupyter Notebook with code and explanations.
# <li>Visualizations showcasing segmentation and insights.
# <li>Concise report summarizing analysis and recommendations.
# </ul>

# %%
#importing Libraries
import pandas as pd

# %%
#Intialising e as entertainer basic table
e=pd.read_excel("Assets\Entertainer - Basic Info.xlsx")

# %%
e
# Out:
#         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
# [70 rows x 3 columns]

# %%
#Intialising eb as entertainer breakthrough table
eb=pd.read_excel("Assets\Entertainer - Breakthrough Info.xlsx")

# %%
eb
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 67     Wayne Newton                                          1972
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                         19                           2009.0
# ...

# %%
#Intialising el as entertainer lastwork
el=pd.read_excel("Assets\Entertainer - Last work Info.xlsx")

# %%
el
# Out:
#         Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0             Adele                                2016            NaN
# 1    Angelina Jolie                                2016            NaN
# 2   Aretha Franklin                                2014            NaN
# 3       Bette Davis                                1989         1989.0
# 4       Betty White                                2016            NaN
# ..              ...                                 ...            ...
# 65        Tom Hanks                                2016            NaN
# 66     Tony Bennett                                2016            NaN
# 67     Wayne Newton                                2016            NaN
# 68       Will Smith                                2016            NaN
# 69    Willie Nelson                                2016            NaN
#
# [70 rows x 3 columns]

# %%
# concating the first two tables (e and eb) 
main = pd.concat([e,eb],axis=1)

# %%
main.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
main1=pd.concat([main,el],axis=1)

# %%
main1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
main1.isnull().sum()
# Out:
# Entertainer                                      0
# Gender (traditional)                             0
# Birth Year                                       0
# Entertainer                                      0
# Year of Breakthrough/#1 Hit/Award Nomination     0
# Breakthrough Name                                0
# Year of First Oscar/Grammy/Emmy                  6
# Entertainer                                      0
# Year of Last Major Work (arguable)               0
# Year of Death                                   40
# dtype: int64

# %%
new_data="entertainer_new.xlsx"
main1.to_excel(new_data)

# %% [markdown]
# <h4>Unified Mentor Data Analytics Internship Project.</h4>
# <p>↪Submitted by : S Sreedhar
